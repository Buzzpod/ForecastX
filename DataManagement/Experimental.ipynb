# %%
import pandas as pd
import yfinance as yf
import numpy as np

msft = yf.Ticker("MSFT")

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'MSFT',
#  'exchangeName': 'NMS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': Timestamp('1986-03-13 09:30:00-0500', tz='America/New_York'),
#  'regularMarketTime': Timestamp('2023-07-07 13:46:15-0400', tz='America/New_York'),
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 341.525,
#  'chartPreviousClose': 323.38,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'end': Timestamp('2023-07-07 09:30:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-07-07 04:00:00-0400', tz='America/New_York')},
#   'regular': {'end': Timestamp('2023-07-07 16:00:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-07-07 09:30:00-0400', tz='America/New_York')},
#   'post': {'end': Timestamp('2023-07-07 20:00:00-0400', tz='America/New_York'),
#    'start': Timestamp('2023-07-07 16:00:00-0400', tz='America/New_York')}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show news
msft.news
# Out:
# [{'uuid': 'f54d75c5-e6ad-39af-a7b5-62eca942c075',
#   'title': '12 Best Momentum Stocks to Buy Today',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/12-best-momentum-stocks-buy-163032664.html',
#   'providerPublishTime': 1688747432,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yhew4P7J4EDov_lGOlGEig--~B/aD04NTU7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/6bb1d8eb85b54c6b741ba52e7feefdcd',
#      'width': 1280,
#      'height': 855,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/MHz5id9fthRl21dS4NatdQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/6bb1d8eb85b54c6b741ba52e7feefdcd',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AVGO',
#    'ADI',
#    'NKE',
#    'XOM',
#    'NVDA',
#    'TJX',
#    'MRK',
#    'MSFT']},
#  {'uuid': '1fae2ef1-5c69-327a-adb8-79a9f02b4760',
#   'title': '14 Best NASDAQ Dividend Stocks To Buy',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/14-best-nasdaq-dividend-stocks-160726731.html',
#   'providerPublishTime': 1688746046,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/nHapb2ivsRUhpnG4b3gLYA--~B/aD00MjI7dz03NTA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/7bccf1845e2d3cc33d5cf6ac7b385a2a',
#      'width': 750,
#      'height': 422,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Bq0PX5zGIXtS2EReW_RTHw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/7bccf1845e2d3cc33d5cf6ac7b385a2a',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['CSCO',
#    'ADI',
#    'CMCSA',
#    'CSX',
#    'GILD',
#    'SBUX',
#    'AVGO',
#    'QCOM',
#    'COST',
#    'NVDA',
#    'MSFT']},
#  {'uuid': '6ceb8cad-6ca6-3834-bc1a-8cbb593e38fa',
#   'title': '15 Best Coding Games to Learn Programming for Beginners',
#   'publisher': 'Insider Monkey',
#   'link': 'https://finance.yahoo.com/news/15-best-coding-games-learn-145531940.html',
#   'providerPublishTime': 1688741731,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/vi5828gaQQQmXGwDAEyRRA--~B/aD05Njk7dz0xOTM3O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/d26d2c55cd027e2b4f44ded4c6ac02d0',
#      'width': 1937,
#      'height': 969,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/e1D1DXlcPcq5isLeKyt.Cg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/d26d2c55cd027e2b4f44ded4c6ac02d0',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'GOOGL']},
#  {'uuid': '803b9d3c-117a-3ea4-b6a7-761db493fa05',
#   'title': 'Microsoft-backed AI4Bharat set to raise $12 million funding from Peak XV, Lightspeed - sources',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/microsoft-backed-ai4bharat-set-raise-145125363.html',
#   'providerPublishTime': 1688741485,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/gI5SXtfp9lpiSErNF.QNhw--~B/aD01MzI7dz04MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters-finance.com/59b91a861a87a69feeb37743c0ada98e',
#      'width': 800,
#      'height': 532,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/sa0ZuDS9eRL8eU8zaubdNQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/reuters-finance.com/59b91a861a87a69feeb37743c0ada98e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': 'd417bee3-f820-332f-8ddb-ffce0465a2eb',
#   'title': 'Microsoft-backed AI4Bharat set to raise $12 mln funding from Peak XV, Lightspeed - sources',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/microsoft-backed-ai4bharat-set-raise-144754174.html',
#   'providerPublishTime': 1688741274,
#   'type': 'STORY',
#   'relatedTickers': ['MSFT']},
#  {'uuid': '3b676dab-866d-3530-9364-d935eb67a663',
#   'title': '3 Supercharged Dividend Growth Stocks to Buy Right Now',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/3b676dab-866d-3530-9364-d935eb67a663/3-supercharged-dividend.html',
#   'providerPublishTime': 1688740200,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/BXJQuyy0F_AH2_dJNtC1TA--~B/aD0xMzkxO3c9MjE1NjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/670badca5dd43767139b27dcff4c2e4e',
#      'width': 2156,
#      'height': 1391,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/BgPT4IoxEZH6XzGzf7Qp8g--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/670badca5dd43767139b27dcff4c2e4e',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'COST', 'SBUX']},
#  {'uuid': 'b8f9d9d8-e761-3876-bd4f-63523e314c72',
#   'title': 'Tesla Stock Revs Up Demand Alongside Microsoft, Axon And More',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/b8f9d9d8-e761-3876-bd4f-63523e314c72/tesla-stock-revs-up-demand.html',
#   'providerPublishTime': 1688740060,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/rmOO9btEULohf6m8PCbnFg--~B/aD01MTE7dz0xMDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/c6ce10ab044a79d8502e066df08506b6',
#      'width': 1000,
#      'height': 511,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/9NlllaDRqabgg2QLQylSlA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/c6ce10ab044a79d8502e066df08506b6',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['TSLA', 'MSFT', 'AVGO']},
#  {'uuid': 'c2948cf8-ffdf-381d-803a-33b2af8a91b0',
#   'title': 'Move Over, FAANG: The "Magnificent 7" Stocks Are Here, and These 2 Might Be the Best Buys',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/c2948cf8-ffdf-381d-803a-33b2af8a91b0/move-over%2C-faang%3A-the.html',
#   'providerPublishTime': 1688738400,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/P5Ep_3He9qfdMXN7jGUX.g--~B/aD0yMTYwO3c9Mzg0MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/0f904bba685efb77a9ad19c7d001ca15',
#      'width': 3840,
#      'height': 2160,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/S63g1kZCze7epB9KZYXhGQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/0f904bba685efb77a9ad19c7d001ca15',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'AMZN', 'NVDA', 'TSLA']}]
